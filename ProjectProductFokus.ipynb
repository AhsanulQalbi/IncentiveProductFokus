# %%
import pandas as pd
import numpy as np
import pandasql as ps

# %%
dataCsv = pd.read_excel('cleanData.xlsx')

# %%
print(dataCsv.head())
# Out:
#    No.      Bulan        NAMACAB                 NAMALANG  \
# 0   80 2020-07-01  BANDARLAMPUNG            INDRA JAYA AP
# 1   81 2020-07-01  BANDARLAMPUNG                ENGGAL AP
# 2   82 2020-07-01  BANDARLAMPUNG     PELITA AP - KESHATAN
# 3   83 2020-07-01  BANDARLAMPUNG  TIJARA ANUGRAH FARMA PT
# 4  311 2020-07-01      TANGERANG                 NIDEA AP
#
#                    NAMAPROD    HNA  BANYAK    THNA  PRSND  DHARGA TYPE OUTLET  \
# 0  PROPEPSA SUSPENSI 200 ML  85000       1   85000      0       0      APOTIK
# 1        D-VIT FLASH TABLET  75000       4  300000      0       0      APOTIK
# 2  PROPEPSA SUSPENSI 100 ML  57500       3  172500      0       0         NaN
# 3  PROPEPSA SUSPENSI 100 ML  57500      12  690000      0       0         PBF
# 4  PROPEPSA SUSPENSI 100 ML  57500       2  115000      0       0         NaN
#
#       SUBRAYON                   AM
# 0  WAY HALIM 3         EKA CHAIRANI
# 1  RADEN INTAN         EKA CHAIRANI
# ...

# %%
dataFrame = pd.DataFrame(dataCsv)

# %%
print(dataFrame)
# Out:
#        No.      Bulan        NAMACAB                 NAMALANG  \
# 0       80 2020-07-01  BANDARLAMPUNG            INDRA JAYA AP
# 1       81 2020-07-01  BANDARLAMPUNG                ENGGAL AP
# 2       82 2020-07-01  BANDARLAMPUNG     PELITA AP - KESHATAN
# 3       83 2020-07-01  BANDARLAMPUNG  TIJARA ANUGRAH FARMA PT
# 4      311 2020-07-01      TANGERANG                 NIDEA AP
# ..     ...        ...            ...                      ...
# 844  21372 2020-07-30  BANDARLAMPUNG        APT POLYGON FARMA
# 845  21373 2020-07-30  BANDARLAMPUNG        APT POLYGON FARMA
# 846  21374 2020-07-30  BANDARLAMPUNG        APT POLYGON FARMA
# 847  21375 2020-07-30  BANDARLAMPUNG        APT POLYGON FARMA
# 848  21376 2020-07-30  BANDARLAMPUNG        APT POLYGON FARMA
#
#                      NAMAPROD     HNA  BANYAK     THNA  PRSND   DHARGA  \
# 0    PROPEPSA SUSPENSI 200 ML   85000       1    85000      0        0
# 1          D-VIT FLASH TABLET   75000       4   300000      0        0
# ...

# %%
apotikTypeoutlet = dataFrame.copy()
apotikTypeoutlet.loc[(distincTypeoutlet['TYPE OUTLET'] == 'APOTIK') | (distincTypeoutlet['TYPE OUTLET'] == 'APOTEK')]
# Out:
#        No.      Bulan        NAMACAB           NAMALANG  \
# 0       80 2020-07-01  BANDARLAMPUNG      INDRA JAYA AP
# 1       81 2020-07-01  BANDARLAMPUNG          ENGGAL AP
# 9      317 2020-07-01      TANGERANG          3 NAGA AP
# 10     318 2020-07-01      TANGERANG          3 NAGA AP
# 11     319 2020-07-01      TANGERANG          3 NAGA AP
# ..     ...        ...            ...                ...
# 844  21372 2020-07-30  BANDARLAMPUNG  APT POLYGON FARMA
# 845  21373 2020-07-30  BANDARLAMPUNG  APT POLYGON FARMA
# 846  21374 2020-07-30  BANDARLAMPUNG  APT POLYGON FARMA
# 847  21375 2020-07-30  BANDARLAMPUNG  APT POLYGON FARMA
# 848  21376 2020-07-30  BANDARLAMPUNG  APT POLYGON FARMA
#
#                      NAMAPROD     HNA  BANYAK     THNA  PRSND   DHARGA  \
# 0    PROPEPSA SUSPENSI 200 ML   85000       1    85000      0        0
# 1          D-VIT FLASH TABLET   75000       4   300000      0        0
# 9               ZEMINDO SYRUP   37500      12   450000     22    99000
# ...

# %%
namaOutlet = apotikTypeoutlet['NAMALANG'].unique()

# %%
print(np.sort(namaOutlet))
# Out:
# ['3 NAGA AP' 'AGUS SANTOSO (APT SHIFA)' 'AL FARIZI AP'
#  'ALENA AP - BANDARLAMPUNG' 'ALINDA HUSADA' 'ALKA FARMA AP' 'ALMADANI AP'
#  'ALPHA AP' 'ALPHARMA AP.' 'AMOR MEDIKA' 'AMORA AP' 'AN- NUR 2 AP'
#  'ANNISA SEHAT AP' 'APOTEK 22 FARMA' 'APOTEK AAN' 'APOTEK ADZRA'
#  'APOTEK AHYA' 'APOTEK BINTARO WOMEN AND CHILDREN CLINIC (BWCC)'
#  'APOTEK PURI BETA' 'APOTEK QARIRA' 'APOTEK SAHABAT' 'APOTEK SEHATI'
#  'APOTEK TAMAN ASRI' 'APT ANGGER' 'APT ANUGRAH MEDIKA' 'APT APT BIOFARMA'
#  'APT APT SABILA' 'APT AQILLA' 'APT BINTANG' 'APT BINTANG I' 'APT CIKO'
#  'APT KIBANG FARMA' 'APT POLYGON FARMA' 'APT RESTU IBU' 'APT SARI FARMA'
#  'APT SURYA' 'APT ZIDAN FARMA' 'APT. NAISYA'
#  'ARBEN SYAMSUAR/FERAWATI (APT HIDAYAH)' 'ARCHA MEDICA AP'
#  'ARRAYA FARMA AP' 'ARTHA MEDICAL CENTER' 'AS-SYIFA AP' 'AURA FARMA AP'
#  'AWAL BROSS AP' "B'WIN" 'BAHARI - SERANG' 'BAHARUDDIN HI AP'
#  'BELLEZA INST RSIA' 'BENGGALA FARMA AP' 'BERSALIN PERMATA IBUNDA RS'
# ...

# %%
print(len(namaOutlet))
# Out:
# 251

# %%
outLetDispensing = []
while (1) :
    userInput = input('Masukkan Nama Outlet Dispensing')
# Out:
# 0                   INDRA JAYA AP
# 1                       ENGGAL AP
# 2            PELITA AP - KESHATAN
# 3         TIJARA ANUGRAH FARMA PT
# 4                        NIDEA AP
#                   ...
# 777                        KF BSD
# 809              APOTEK PURI BETA
# 811          LILY MEDIKA SEHAT AP
# 823    RSU GLADISH MEDICAL CENTRE
# 828             APT POLYGON FARMA
# Name: NAMALANG, Length: 251, dtype: object
